# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df_input=pd.read_csv("insurance.csv")
df_input
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
df_input.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
df_input = pd.get_dummies(df_input,columns=['sex','smoker','children','region'])
# children is taken as a qualitative data bcus num of children cant take more than 10 i mean its illogical to treat it as a quantitative variable , so we are encoding it.

df_input# df_input=df_input.drop(columns=['sex','smoker'])
# df_input._append(df_encoded)
# df_input
# Out:
#       age     bmi      charges  sex_female  sex_male  smoker_no  smoker_yes  \
# 0      19  27.900  16884.92400        True     False      False        True
# 1      18  33.770   1725.55230       False      True       True       False
# 2      28  33.000   4449.46200       False      True       True       False
# 3      33  22.705  21984.47061       False      True       True       False
# 4      32  28.880   3866.85520       False      True       True       False
# ...   ...     ...          ...         ...       ...        ...         ...
# 1333   50  30.970  10600.54830       False      True       True       False
# 1334   18  31.920   2205.98080        True     False       True       False
# 1335   18  36.850   1629.83350        True     False       True       False
# 1336   21  25.800   2007.94500        True     False       True       False
# 1337   61  29.070  29141.36030        True     False      False        True
#
# ...

# %%
x=df_input
x=x.drop(columns='charges')
x
# Out:
#       age     bmi  sex_female  sex_male  smoker_no  smoker_yes  children_0  \
# 0      19  27.900        True     False      False        True        True
# 1      18  33.770       False      True       True       False       False
# 2      28  33.000       False      True       True       False       False
# 3      33  22.705       False      True       True       False        True
# 4      32  28.880       False      True       True       False        True
# ...   ...     ...         ...       ...        ...         ...         ...
# 1333   50  30.970       False      True       True       False       False
# 1334   18  31.920        True     False       True       False        True
# 1335   18  36.850        True     False       True       False        True
# 1336   21  25.800        True     False       True       False        True
# 1337   61  29.070        True     False      False        True        True
#
#       children_1  children_2  children_3  children_4  children_5  \
# ...

# %%
y=df_input['charges']
y
# Out:
# 0       16884.92400
# 1        1725.55230
# 2        4449.46200
# 3       21984.47061
# 4        3866.85520
#            ...
# 1333    10600.54830
# 1334     2205.98080
# 1335     1629.83350
# 1336     2007.94500
# 1337    29141.36030
# Name: charges, Length: 1338, dtype: float64

# %%
import seaborn as sns

# %%
corr= df_input.corr()
plt.figure(figsize=(10,8), dpi =500)
sns.heatmap(corr,annot=True,fmt=".2f", linewidth=.5)
plt.show()
# remove variables that are highly correlated and which are co(edge colors in the heat map)
# lets choose age bmi and smoker_yes for the fit

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(x,y,test_size=0.3,random_state=23)

# %%
lr=LinearRegression()
x_train_modi=X_train[['age','bmi','smoker_yes']]
model=lr.fit(x_train_modi,y_train)

# %%
# print(X_test)
lr.score(X_test[['age','bmi','smoker_yes']],y_test)
# Out:
# 0.7312797249781074
