# %% [markdown]
# Lasso Regression from scratch

# %%
import matplotlib.pyplot as plt
import statistics
import numpy as np

# %%
y_actual=np.array([10,12,22,12,20,21,23,26,34,49])
X=np.array([3,4,6,4,5,12,8,7,9,10])

# %%
def LassoRegression(x,y_actual):
    m,c=0,0
    num,deno=0,0
    l=0.1
    x_mean=statistics.mean(x)
    y_mean=statistics.mean(y_actual)
    num=(sum(x*y_actual)-y_mean*sum(x))-l
    deno=sum(x**2)-x_mean*sum(x)
    m=num/deno 
    c=(y_mean-m*x_mean)
    return m,c

# %%
m,c=LassoRegression(X,y_actual)
print(m,c)
# Out:
# 2.090151515151515 9.45909090909091

# %%
y_pred=X*m+c
rss=sum((y_pred-y_actual)**2)
tss=sum((y_actual-statistics.mean(y_actual))**2)
r2=1-(rss/tss)
print(r2)
plt.plot(X,y_pred)
plt.scatter(X,y_actual)
plt.show()
# Out:
# 0.45282782146803724

# %% [markdown]
# Lasso Regression using Sklearn

# %%
from sklearn.linear_model import Lasso
y_actual=np.array([10,12,22,12,20,21,23,26,34,49])
x=np.array([3,4,6,4,5,12,8,7,9,10])

# %%
x_modi=x.reshape(-1, 1)
regr = Lasso()
regr.fit(x_modi, y_actual)
inter=regr.intercept_
slope=regr.coef_

# %%
rss,tss=0,0
y_pred=(slope*x+inter)
plt.figure()
plt.scatter(x,y_actual)
plt.plot(x,y_pred)
plt.show()
rss=sum((y_pred-y_actual)**2)
tss=sum((y_actual-statistics.mean(y_actual))**2)
r2=1-(rss/tss)
print(r2*100,slope,inter)
# Out:
# 48.538062787582284 [2.63917526] 4.953608247422675
